# %%
import numpy as np
import pandas as pd
import sklearn as skl

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
# This data is from here: https://zenodo.org/records/11295916
df = pd.read_csv("../data/raw/accepted_2007_to_2018Q4.csv")
df.head(10)

# %%
df.shape

# %%
dtypes = df.dtypes
dtypes.sort_index()

# %%
dates = df[['loan_status','id','issue_d', 'last_credit_pull_d', 'last_pymnt_d', 'next_pymnt_d']]
dates
# OK, so this loans data is as of 2019 for all of their loans they gave out between 2008 and to 2018 as at 2018

# %%
loan_status = df['loan_status'].value_counts()
loan_status
